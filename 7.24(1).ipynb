# %% [markdown]
# # 更多字符串和特殊方法
# - 前面我们已经学了类，在Python中还有一些特殊的方法起着非常重要的作用，这里会介绍一些特殊的方法和运算符的重载，以及使用特殊方法设计类

# %%
a='zzzz'
print(a)
# Out:
# zzzz

# %%
b=str()
b
# Out:
# ''

# %%
b=str(1234)
b
# Out:
# '1234'

# %%
b=str([12,3,4])
b
# Out:
# '[12, 3, 4]'

# %% [markdown]
# ## str 类
# - 一个str对象是不可变的，也就是说，一旦创建了这个字符串，那么它的内容在认为不改变的情况下是不会变的
# - s1 = str()
# - s2 = str('welcome to Python')

# %% [markdown]
# ## 创建两个对象，分别观察两者id
# - id为Python内存地址

# %%
print(id('a'))
print(id('b'))
# Out:
# 1886203259232
# 1886203257552

# %%
a='a'
b='a'
print(id(a))
print(id(a))
# Out:
# 1886203259232
# 1886203259232

# %% [markdown]
# ## 处理字符串的函数
# - len长度
# - max
# - min
# - 字符串一切是按照ASCII码值进行比较

# %%
len('abc')
# Out:
# 3

# %%
i=0
a='abcde'
while i<len(a):
    print(a[i])
    i+=1
# Out:
# a
# b
# c
# d
# e

# %% [markdown]
# ## 下角标运算符 []
# - 一个字符串是一个字符序列，可以通过索引进行访问
# - 观察字符串是否是一个可迭代序列  \__iter__

# %%
a='zjg' #下角标运算
a[0]
# Out:
# 'z'

# %%
a='jingwang'
a[-1]
# Out:
# 'g'

# %%
a='jingwang'
a[::-1]
# Out:
# 'gnawgnij'

# %% [markdown]
# ## 切片 [start: end]
# - start 默认值为0
# - end 默认值为-1

# %%
a='http://www.w3csshool.cn/python3/python-string.htum'
a1=a[0:7]
a2=a[7:10]
a3=a[11:23]
a4=a[24:32]
a5=a[32:-1]
b=a[1::5]
print(a1)
print(a2)
print(a3)
print(a4)
print(a5)
print(b)
# Out:
# http://
# www
# w3csshool.cn
# python3/
# python-string.htu
# t/whct/orh

# %% [markdown]
# ## 链接运算符 + 和复制运算符 *
# - \+ 链接多个字符串，同时''.join()也是
# - \* 复制多个字符串

# %%
's'+2

# %%
's'*2
# Out:
# 'ss'

# %%
a1='#'*5
a2='#'+' '+' '+' '+' '+'#'
a3='#'+' '+' '+' '+' '+'#'
a4='#'*5
print(a1,a2,a3,a4,end='')
         if count%5==0:
               print('\n')
# Out:
#   File "<ipython-input-47-d3516cea6d64>", line 6
#     if count%5==0:
#     ^
# IndentationError: unexpected indent

# %%
foe i in range(0,4):
    if i==0 or i==3:
        print('*'*5)
    else:
        print('*'+' '*3+'*')
# Out:
#   File "<ipython-input-50-11d166463117>", line 1
#     foe i in range(0,4):
#         ^
# SyntaxError: invalid syntax

# %%
'!'.join('abc') #a!+b!+c!
# Out:
# 'a!b!c'

# %%
a='http://www.w3csshool.cn/python3/python-string.htum''

# %%
import requests

# %%
for i in range(1,5):
    a='http://www.w3csshool.cn/python'+str(i)'/python-string.htum'
requests.get('a')
res.text

# %% [markdown]
# ## in 和 not in 运算符
# - in :判断某个字符是否在字符串内
# - not in ：判断某个字符是否不在字符串内
# - 返回的是布尔值

# %%
'a' in 'aaa'
# Out:
# True

# %%
a='这一生需要徒手攀过高山多少座'
b='这一生'

# %%
def xx(a,b):
    for i in a:
        for j in b:
            if i==j:
                return True

# %% [raw]
# xx(a,b)

# %%
path='/Users/aptx4/Desktop/基础/课件/mail.txt'
with open(path) as f:
    for i in range(50000):
        lines=f.readline()
        print(lines)
if a=='1########@qq.com':
    print(a)
# Out:
# kcqer@vip.qq.com
#
# 4750082@qq.com
#
# beyond.w@qq.com
#
# 326719610@qq.com
#
# 519203740@qq.com
#
# 41654522@.qq.com
#
# 258109664@qq.com
#
# www.372968559@qq.com
#
# 690326585@qq.com
#
# yilvwen@qq.com
#
# 49524476@qq.com
#
# 275141514@qq.com
#
# 77303043@qq.com
#
# yufeng5188@qq.com
#
# 442852203@qq.com
#
# 350191363@qq.com
#
# 295088868@qq.com
#
# 279690888@qq.com
#
# 373017622@qq.com
#
# 349094820@qq.com
#
# 328184981@qq.com
#
# bn922@qq.com
#
# 457271598@qq.com
#
# 462743251@qq.com
#
# 349127247@qq.com
#
# 165279069@qq.com
#
# hhhhhhddddddmmmmmm@qq.com
#
# 385368599@qq.com
#
# 327449705@qq.com
#
# 245911391@qq.com
#
# 5952179@qq.com
#
# 553434719@qq.com
#
# 154790981@qq.com
#
# 277054780@qq.com
#
# 5111719638@qq.com
#
# 742807885@qq.com
#
# 651493465@qq.com
#
# 472935516@qq.com
#
# 270153221@qq.com
#
# 7433159@qq.com
#
# 281131064@qq.com
#
# 78877314@qq.com
#
# 352750777@qq.com
#
# 139615818@qq.com
#
# 404674604@qq.com
#
# 669505006@qq.com
#
# 654667355@qq.com
#
# ...

# %%
a='abcse'
a1=a[3:5]
a2=a[0]
a3=a[2]+a2
a4=a1+' '+a2+' '+a3
print(a4)
# Out:
# se a ca

# %% [markdown]
# ## 比较字符串
# -  ==, !=, >=, <=, >, <
# - 依照ASCII码值进行比较

# %% [markdown]
# ## 测试字符串
# ![](../Photo/99.png)
# - 注意：
# > - isalnum() 中是不能包含空格，否则会返回False

# %% [markdown]
# ## 搜索子串
# ![](../Photo/100.png)

# %% [markdown]
# ## 转换字符串
# ![](../Photo/101.png)

# %% [markdown]
# ## 删除字符串
# ![](../Photo/146.png)

# %% [markdown]
# ## 格式化字符串
# ![](../Photo/103.png)

# %% [markdown]
# ## EP:
# - 1
# ![](../Photo/104.png)
# - 2
#     随机参数100个数字，将www.baidu.com/?page=进行拼接

# %% [markdown]
# ## Python高级使用方法 -- 字符串
# - 我们经常使用的方法实际上就是调用Python的运算重载
# ![](../Photo/105.png)

# %% [markdown]
# # Homework
# - 1
# ![](../Photo/106.png)

# %%
a=[[1,2,3],[4,5],[7,7,7,7]]
b=input( )
c=input( )
d=input( )
if [[b],[c],[d]] in a:
    print('Valid SSN')
else:
    print('Invalid SSN')
# Out:
# 1,2,3
# 4,4
# 7,7,7,7
# Invalid SSN

# %% [markdown]
# - 2
# ![](../Photo/107.png)

# %% [markdown]
# - 3
# ![](../Photo/108.png)

# %%
a1='a,p,t,x'
a2=[4,8,6,9]
b=input('请输入密码：')
if b in a1 and b in a2:
    print('valid password')
else:
    print('invalid password')
# Out:
# 请输入密码：aptx4869
# invalid password

# %% [markdown]
# - 4
# ![](../Photo/109.png)

# %%
def countletters(s):
    number=char=space=other=0
    for char in s:
        if char.isdigit():
            number+=1
        elif char.isalpha():
            char+=1
        else:
            other+=1
print('请输入一个字符串：')
# Out:
# 请输入一个字符串：

# %% [markdown]
# - 5
# ![](../Photo/110.png)

# %%
import re
totalCount=input('请输入一个电话号码：')
totalCount=re.sub('\d','', totalCount)
print(totalCount)
re.sub(pattern, repl, string, count=0, flags=0)

# %% [markdown]
# - 6
# ![](../Photo/111.png)

# %%
def myreverse3(s):
    l = list(s)
    newl = sorted(l,key = None,reverse = True)
    news = ''.join(newl)
    return news
print(myreverse3('请输入一个字符串：'))
# Out:
# ：输请符字入串个一

# %% [markdown]
# - 7
# ![](../Photo/112.png)

# %% [markdown]
# - 8
# ![](../Photo/113.png)

# %%
input('请输入一个字符串：',d1,d2,d3,d4,d5,d6,d7,d8,d9,d10,d11,d12)
d=d1+(3*d2)+d3+(3*d4)+d5+(3*d6)+d7+(3*d8)+d9+(3*d10)+d11+(3*d12)
d13=10-d%10
if d13==10:
    print(d1+d2+d3+d4+d5+d6+d7+d8+d9+d10+d11+d12+0)
else:
    print(d1+d2+d3+d4+d5+d6+d7+d8+d9+d10+d11+d12+d13)

# %% [markdown]
# - 9
# ![](../Photo/114.png)
